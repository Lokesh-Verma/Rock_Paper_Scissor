# %%
rock = '''
    _______
---'   ____)
      (_____)
      (_____)
      (____)
---.__(___)
'''

paper = '''
    _______
---'   ____)____
          ______)
          _______)
         _______)
---.__________)
'''

scissors = '''
    _______
---'   ____)____
          ______)
       __________)
      (____)
---.__(___)
'''
print("Welcome to the game Rock, Paper and Scissors!!!")
choice=int(input("Choose 1 for rock, 2 for paper and 3 for scissor\n"))
import random
cr=[rock,paper,scissors]
cc=random.randint(0,2)
if choice==1:
    print(f" You chose\n{rock}")
    if  cc==0:
        print("Computer\n")
        print(cr[cc])
        print("\nGame is tie. Try again")
    elif cc==1:
        print("Computer\n")
        print(cr[cc])
        print("\nYou Lose. Better Luck next time.")
    else:
        print("Computer\n")
        print(cr[cc])
        print("\nYou Won. Congratulations!!") 
elif choice==2:
    print(f" You chose\n{paper}")
    if  cc==0:
        print("Computer\n")
        print(cr[cc])
        print("\nYou Won. Congratulations!!")
    elif cc==1:
        print("Computer\n")
        print(cr[cc])
        print("\nGame is tie. Try again")
    else:
        print("Computer\n")
        print(cr[cc])
        print("\nYou Lose. Better Luck next time.")
elif choice==3:
    print(f" You chose\n{scissors}")
    if cc==0:
        print("Computer\n")
        print(cr[cc])
        print("\nYou Lose. Better Luck next time.")
    elif cc==1:
        print(scissors)
        print("Computer\n")
        print(cr[cc])
        print("\nYou Won. Congratulations!!")
    else:
        print("Computer\n")
        print(cr[cc])
        print("\nGame is tie. Try again")
# Out:
# Welcome to the game Rock, Paper and Scissors!!!
# Choose 1 for rock, 2 for paper and 3 for scissor
# 2
#  You chose
#
#     _______
# ---'   ____)____
#           ______)
#           _______)
#          _______)
# ---.__________)
#
# Computer
#
#
#     _______
# ---'   ____)
#       (_____)
#       (_____)
#       (____)
# ---.__(___)
#
#
# You Won. Congratulations!!
